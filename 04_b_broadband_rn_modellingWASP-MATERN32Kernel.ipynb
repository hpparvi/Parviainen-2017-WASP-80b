# %% [markdown]
# # Parameter estimation from the broadband light curve assuming red noise this is with Matern32Kernel, and only masked data was analysed to save time

# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
import math as mt
import pandas as pd
import seaborn as sb

from IPython.html.widgets import Text, IntProgress, HBox, VBox, HTML
from pandas import HDFStore
from emcee import EnsembleSampler
from pyde.de import DiffEvol

from src.lpf_wr import LPFunctionRN
from src.core import *

pb_filter_bb.name = 'white'
# Out:
# :0: FutureWarning: IPython widgets are experimental and may change in the future.

# %% [markdown]
# ## Create a wrapper class for the parameter estimation
#
# We have two versions of the white light curve: one without masking of the spectrum and one with masking.

# %%
class PE(object):
    def __init__(self, wfname, n_walkers=100, n_threads=4):
        df_aux = pd.read_hdf('results/light_curves.h5', 'aux')
        df_lc  = pd.read_hdf('results/light_curves.h5', wfname)
        msk = array(df_aux.bad_mask, dtype=np.bool)
        
        self.lpf = LPFunctionRN(array(df_aux.mjd+0.5)[msk], df_lc.white[msk], df_aux.airmass[msk], n_threads)
        self.de = DiffEvol(self.lpf, self.lpf.ps.bounds, n_walkers, maximize=True, C=0.85, F=0.25)
        self.sampler = EnsembleSampler(self.de.n_pop, self.lpf.ps.ndim, self.lpf) 
                              
        qc = self.lpf.lds.coeffs_qd()[0][0]
        self.de._population[:,8] = normal(qc[0], 0.05, size=n_walkers) 
        self.de._population[:,9] = normal(qc[1], 0.05, size=n_walkers)
                  
            
    def run_de(self, n_iter=250):
        wp = IntProgress(value=0, max=n_iter)
        wh = HTML(value='inf')
        wb = VBox(children=[wp,wh])
        display(wb)
        for i, p in enumerate(self.de(n_iter)):
            if i%25 == 0:
                wp.value += 25
                wh.value = 'DE maximum log posterior {:10.3f}'.format(-self.de.minimum_value)
            
            
    def run_mcmc(self, n_iter=2500, thin=50):
        pbar = IntProgress(max=n_iter)
        display(pbar)
        for i, c in enumerate(self.sampler.sample(self.de.population, iterations=n_iter, thin=thin)):
            if i%50 == 0:
                pbar.value += 50
                
                
    def create_dataframe(self, burn=0, thin=1):
        self.df = pd.DataFrame(self.fc(burn,thin), columns=self.lpf.ps.names)
        self.df['k'] = sqrt(self.df['k2'])
        return self.df     
                
        
    def fc(self, burn=0, thin=1):
        return self.chain[:,burn::thin,:].reshape([-1, self.chain.shape[2]])

    
    @property
    def chain(self):
        return self.sampler.chain

# %% [markdown]
# ## Run the masked LC analysis

# %%
pe_m = PE('final/bb_masked')
pe_m.run_de(100)
pe_m.run_mcmc(1000)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-19-ee3a7aa3ebec> in <module>()
# ----> 1 pe_m = PE('final/bb_masked')
#       2 pe_m.run_de(100)
#       3 pe_m.run_mcmc(1500)
#
# <ipython-input-3-f3be55d88f58> in __init__(self, wfname, n_walkers, n_threads)
#       5         msk = array(df_aux.bad_mask, dtype=np.bool)
#       6
# ----> 7         self.lpf = LPFunctionRN(array(df_aux.mjd+0.5)[msk], df_lc.white[msk], df_aux.airmass[msk], n_threads)
#       8         self.de = DiffEvol(self.lpf, self.lpf.ps.bounds, n_walkers, maximize=True, C=0.85, F=0.25)
#       9         self.sampler = EnsembleSampler(self.de.n_pop, self.lpf.ps.ndim, self.lpf)
#
# /home/mert3269/soft/Parviainen-WASP-80b-Osiris/src/lpf_wr.py in __init__(self, time, flux, airmass, nthreads)
#      17 class LPFunctionRN(LPFunction):
#      18     def __init__(self, time, flux, airmass, nthreads=2):
# ---> 19         super(LPFunctionRN, self).__init__(time, flux, airmass, nthreads)
#      20         #self.gp = GP(ExpKernel(1))
#      21         self.gp = GP(Matern32Kernel(1)) #here
#
# /home/mert3269/soft/Parviainen-WASP-80b-Osiris/src/lpf_ww.pyc in __init__(self, time, flux, airmass, nthreads, filters)
#      22         self.npb      = 1
#      23
# ---> 24         sc = LDPSetCreator(teff=(5650,35),logg=(4.58,0.015),z=(-0.19,0.08), filters=filters or [pb_filter_bb])
#      25         self.lds = sc.create_profiles(500)
#      26         self.lds.resample_linear_z()
#
# /home/mert3269/Library/Python/2.7/lib/python/site-packages/ldtk/ldtk.pyc in __init__(self, teff, logg, z, filters, qe, limits, force_download)
#     387             w = f(wl) * self.qe(wl)
#     388             for did,df in enumerate(self.files):
# --> 389                 self.fluxes[fid,did,:]  = (pf.getdata(df)*w).mean(1)
#     390                 self.fluxes[fid,did,:] /= self.fluxes[fid,did,-1]
#     391
#
# KeyboardInterrupt:

# %%
pe_mbig = PE('final/bb_masked')
pe_mbig.run_de(100)
pe_mbig.run_mcmc(1500)

# %%
fig,ax = subplots(1,1)
ax.plot(pe_m  .chain[:,5:,0].T, 'k', alpha=0.1)
fig.tight_layout()

# %% [markdown]
# ## Create and save the dataframes

# %%
#dfn = pe_n.create_dataframe(10,2)
dfmbig = pe_mbig.create_dataframe(5)

# %%
hdf = HDFStore(join('results','pe.h5'))
#hdf.put('bb/rn_nomaskmat', dfn, format='table', data_columns=True)
hdf.put('bb/rn_maskedmat2', dfm, format='table', data_columns=True)
hdf.close()

# %%
pe_m.sampler.acor
# Out:
# array([  1.57451829e-12,   3.33066907e-16,   3.21964677e-15,
#          4.44089210e-15,   5.10702591e-15,  -2.22044605e-16,
#          3.88578059e-15,   4.44089210e-15,  -8.88178420e-16,
#         -6.66133815e-16,   6.43929354e-15,   2.88657986e-15])

# %% [markdown]
# ## Plots

# %%
def get_range(p):
    pn = percentile(dfn[p], [0.25,99.75])
    pm = percentile(dfm[p], [0.25,99.75])
    return [min(pn[0],pm[0]),max(pn[1],pm[1])]

# %%
#dfn['e_ppm'] = 1e6*dfn.e
dfm['e_ppm'] = 1e6*dfm.e

pars = 'tc rho b k e_ppm c x u v'.split()
cp = sb.color_palette()

with sb.axes_style('ticks'):
    fig,axs = subplots(3,3,figsize=(14,8))
    for i,p in enumerate(pars):
        #rng = get_range(p)
        #dfn[p].hist(ax=axs.flat[i], bins=30, fc=cp[0],  label='no mask', grid=False, alpha=0.75)
        dfm[p].hist(ax=axs.flat[i],bins=30, fc=cp[1],  label='masked', grid=False, alpha=0.75)
        setp(axs.flat[i].get_yticklabels(), visible=False)
    axs.flat[0].legend()
    sb.despine(fig)
    fig.tight_layout()

# %% [markdown]
# ---
# <center> &copy; 2015 <a href="mailto:hannu.parviainen@physics.ox.ac.uk">Hannu Parviainen</a></center>
