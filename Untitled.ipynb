# %%
from core import *
import numpy as np

# %%
l_obj
# Out:
# ['/home/mert3269/soft/Parviainen-WASP-80b-Osiris/data/object/0000705485-20140825-OSIRIS-OsirisLongSlitSpectroscopy.fits',
#  '/home/mert3269/soft/Parviainen-WASP-80b-Osiris/data/object/0000705486-20140825-OSIRIS-OsirisLongSlitSpectroscopy.fits',
#  '/home/mert3269/soft/Parviainen-WASP-80b-Osiris/data/object/0000705487-20140825-OSIRIS-OsirisLongSlitSpectroscopy.fits',
#  '/home/mert3269/soft/Parviainen-WASP-80b-Osiris/data/object/0000705488-20140825-OSIRIS-OsirisLongSlitSpectroscopy.fits',
#  '/home/mert3269/soft/Parviainen-WASP-80b-Osiris/data/object/0000705489-20140825-OSIRIS-OsirisLongSlitSpectroscopy.fits',
#  '/home/mert3269/soft/Parviainen-WASP-80b-Osiris/data/object/0000705490-20140825-OSIRIS-OsirisLongSlitSpectroscopy.fits',
#  '/home/mert3269/soft/Parviainen-WASP-80b-Osiris/data/object/0000705491-20140825-OSIRIS-OsirisLongSlitSpectroscopy.fits',
#  '/home/mert3269/soft/Parviainen-WASP-80b-Osiris/data/object/0000705492-20140825-OSIRIS-OsirisLongSlitSpectroscopy.fits',
# ...

# %%
bmsk = np.ones(650, np.bool)
#bmsk[317:320] = 0
bmsk[630:] = 0

# %%
l_obj[317]
# Out:
# False

# %%
type(l_obj)
# Out:
# list

# %%
print [lst[i] for i in xrange(len(lst)) if msk[i]]
